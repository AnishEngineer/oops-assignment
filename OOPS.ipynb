# %% [markdown]
# #1. What is Object-Oriented Programming (OOP)?
#
#
# Ans:-  Object-Oriented Programming (OOP) is a programming paradigm based on the concept of "objects", which are instances of classes. These objects can contain data in the form of fields (also known as attributes or properties), and code in the form of methods (functions associated with an object).
#
# The core idea is to model software around real-world entities, making programs easier to understand, maintain, and scale.
#
# 💡 Key Concepts of OOP:
# Class
# A blueprint for creating objects. It defines the attributes and methods that the objects created from it will have.
#
# Object
# An instance of a class. It's a specific implementation that holds actual data.
#
# Encapsulation
# Bundling the data (attributes) and methods (functions) that operate on the data into a single unit (object). It also hides the internal state of the object from the outside (data hiding).
#
# Abstraction
# Hiding complex implementation details and showing only the essential features of the object.
#
# Inheritance
# A way to form new classes using classes that have already been defined. The new class (child or subclass) inherits attributes and methods from the existing class (parent or superclass).
#
# Polymorphism
# The ability to use a single interface to represent different underlying data types. For example, a method name can be used for different types of behavior depending on the object that calls it.
#
#
#
# #2. What is a class in OOP?
#
# Ans:- A blueprint for creating objects. It defines the attributes and methods that the objects created from it will have.
#
# #3.What is an object in OOP?
#
# Ans:- In Object-Oriented Programming (OOP), an object is a self-contained unit that consists of:
#
# Attributes (or properties): The data or state of the object.
#
# Methods (or functions): The behaviors or actions the object can perform.
#
# An object is created from a class, which acts like a blueprint. While the class defines the structure, the object is the actual instance with real values.
#
# #4.  What is the difference between abstraction and encapsulation?
# Ans:- Encapsulation Bundling the data (attributes) and methods (functions) that operate on the data into a single unit (object). It also hides the internal state of the object from the outside (data hiding).
#
# #5.What are dunder methods in Python?
#
# Ans:- Dunder methods (short for “double underscore” methods) in Python are special methods that start and end with double underscores, like __init__, __str__, or __add__.
#
# They are also called magic methods, and they let you define how objects of your class behave with built-in operations like printing, adding, comparing, etc.
#
# #6. Explain the concept of inheritance in OOP.
# Ans:- Inheritance is an OOP concept where a class (called the child or subclass) inherits the properties and behaviors (methods and attributes) of another class (called the parent or superclass).
#
# It helps in code reusability and establishes a "is-a" relationship between classes.
#
# #7. What is polymorphism in OOP.
# Ans:- Polymorphism means "many forms." In Object-Oriented Programming, it refers to the ability of different objects to respond to the same method name in different ways.
#
# It allows you to write code that works on objects of different classes as long as they follow the same interface or have similar methods.
#
# #8. How is encapsulation achieved in Python?
# Ans:- Encapsulation is an OOP concept that means wrapping data (attributes) and methods (functions) that operate on the data into a single unit — the object.
#
# It also means restricting access to some parts of an object to protect the internal state. Think of it like putting data behind a protective barrier and only allowing controlled access.
#
# #9. What is a constructor in Python?
#
# Ans:-In Python (and OOP in general), a constructor is a special method used to initialize objects when a class is instantiated.
#
# In Python, the constructor is always named __init__.
#
#
# #10.What are class and static methods in Python?
# Ans:- class methods and static methods in Python, two powerful tools for writing clean and organized object-oriented code.
#
# #11.What is method overloading in Python?
# Ans:-Method Overloading means having multiple methods with the same name in a class, but with different parameters (number or type). It's a way to let a method behave differently depending on the arguments passed to it.
#
#
# #12. What is method overriding in OOP?
# Ans:-Method overriding is when a child class defines a method with the same name as a method in its parent class, but changes its behavior.
#
# When you call that method on an object of the child class, the child’s version of the method is used — even if the object is being referenced as a parent type.
#
# #13. What is a property decorator in Python?
#
# Ans:-The  Property decorator allows you to define a method that can be accessed like an attribute — meaning you can call a method without parentheses, and it feels like accessing a variable.
#
# #14. Why is polymorphism important in OOP?
#
# Here are the main benefits:
#
# 1. ✅ Simplifies Code
# You can write general-purpose functions that work with a variety of object types.
#
# 2. 🔄 Enables Flexible and Extensible Code
# You can add new classes with their own implementation of shared methods without changing existing code.
#
# 3. 🧱 Supports Code Reuse
# Reuse functions and classes in different contexts — makes code DRY (Don’t Repeat Yourself).
#
# 4. 🔒 Encapsulates Behavior
# You don’t need to know an object’s class — just that it can perform the method you're calling.
#
# 5. 📦 Key to Interfaces and Abstract Base Classes
# Polymorphism enables patterns like duck typing and the use of interfaces/abstract classes to define behavior expectations.
#
#
# #15.What is an abstract class in Python?
#
# Ans:-An abstract class in Python is a class that cannot be instantiated on its own and is meant to be inherited by other classes. It often serves as a blueprint for other classes, enforcing that certain methods must be implemented in any subclass.
#
#
# #16.   What are the advantages of OOP?
# Ans:- OOP (Object-Oriented Programming Plus) isn't a universally defined term like OOP, but it's often used informally to describe enhanced or modern OOP practices that incorporate newer paradigms and improvements.
#
#
# #17.What is the difference between a class variable and an instance variable?
# Ans:-
# Instance Variable:
#
#             Belongs to one object
#
#             Unique for each instance
#
#             Defined inside the constructor
#
# Class Variable:
#
#             Belongs to the class itself
#
#             Shared across all instances
#
#             Defined outside any method in the class body
#
#
#
# #18.What is multiple inheritance in Python?
#
# Ans:- Multiple inheritance means a class can inherit from more than one parent class.
#
# So, a subclass gets the methods and attributes from multiple base classes.
#
#
#
# #19. Explain the purpose of ‘’__str__’ and ‘__repr__’ ‘ methods in Python.
#
# Ans:-  In Python, the __str__ and __repr__ methods are special methods used to define how objects of a class are represented as strings. They serve slightly different purposes, and here's a breakdown of each:
#
# __str__(self)
# Purpose: Returns a user-friendly string representation of the object.
#
# Used by: str() function and print() statements.
#
# Goal: Meant to be readable and nicely formatted for end users
#
#
#
# __repr__(self)
# Purpose: Returns a developer-friendly string representation of the object.
#
# Used by: repr() function and interactive interpreter (e.g., Jupyter, Python shell).
#
# Goal: Meant to be unambiguous, often including details useful for debugging. Ideally, it should return a string that could be used to recreate the object (if possible).
#
#
#
# #20. What is the significance of the ‘super()’ function in Python.
#
# Ans:-super() is a built-in function in Python that gives you access to methods from a parent or sibling class — without explicitly naming them.
#
# You typically use it in inheritance to call methods from the superclass (i.e., parent class).
#
#
# #21.What is the significance of the __del__ method in Python?
#
# Ans:- The __del__ method in Python is a special method known as a destructor. It's automatically called when an object is about to be destroyed, typically when there are no more references to it. Its main role is to handle cleanup activities before the object is removed from memory. For example, if an object opened a file or held a network connection, the __del__ method can be used to close the file or disconnect safely.
#
#
# #22.What is the difference between @staticmethod and @classmethod in Python?
# Ans:-In Python, both @staticmethod and @classmethod are decorators used to define methods that are not regular instance methods, but they serve different purposes and behave differently.
#
# A @staticmethod is a method that does not take a reference to the class or instance as its first argument. It behaves just like a regular function but lives inside the class's namespace. It doesn’t know anything about the class or instance—it's simply a utility function that’s grouped with the class for organizational reasons.
#
# On the other hand, a @classmethod takes the class itself (cls) as the first argument, rather than the instance (self). This means it has access to class-level data and can modify class state. It’s often used for factory methods, where you want to create class instances in a specific way, or to operate on class variables that are shared among all instances.
#
#
#
#
# #23.How does polymorphism work in Python with inheritance.
#
#
# Ans:- Polymorphism in Python works beautifully with inheritance by allowing different classes in the same inheritance hierarchy to provide their own implementations of a method while sharing the same method name. This means you can write code that works on a superclass type but behaves differently depending on which subclass is actually being used — all without changing the code that calls the method.
#
#
# #24. What is method chaining in Python OOP?
# Ans:- Method chaining in Python (especially in object-oriented programming) is a technique where multiple method calls are made in a single line, one after another, using dot (.) notation. Each method returns the object itself (usually self), allowing the next method to be called on the same object.
#
#
# #25. What is the purpose of the __call__ method in Python?
# Ans:- The __call__ method in Python is a special (or "dunder") method that allows an instance of a class to be called as if it were a function.
#
# Purpose of __call__:
# It enables objects to behave like functions. When you define __call__ in a class, you can "call" an instance of that class using parentheses and pass arguments to it, just like you would with a regular function.

# %%
#1. Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog that overrides the speak() method to print "Bark!".



class Animal:
    def speak(self):
        print("Animal speaks")

# %% [markdown]
# #2. Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle from it and implement the area() method in both.
#
#
# Ans:-
#
# # Abstract base class
# class Shape(ABC):
#     @abstractmethod
#     def area(self):
#         pass
#
# # Circle class
# class Circle(Shape):
#     def __init__(self, radius):
#         self.radius = radius
#
#     def area(self):
#         return math.pi * self.radius ** 2
#
# # Rectangle class
# class Rectangle(Shape):
#     def __init__(self, width, height):
#         self.width = width
#         self.height = height
#
#     def area(self):
#         return self.width * self.height
#
# # Example usage
# if __name__ == "__main__":
#     circle = Circle(5)
#     rectangle = Rectangle(4, 6)
#
#     print(f"Area of Circle: {circle.area():.2f}")
#     print(f"Area of Rectangle: {rectangle.area():.2f}")

# %%
#3. Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car and further derive a class ElectricCar that adds a battery attribute.

Ans:-

# Base class
class Vehicle:
    def __init__(self, vehicle_type):
        self.type = vehicle_type

    def display_info(self):
        print(f"Vehicle Type: {self.type}")

# Derived class
class Car(Vehicle):
    def __init__(self, vehicle_type, brand):
        super().__init__(vehicle_type)
        self.brand = brand

    def display_info(self):
        super().display_info()
        print(f"Brand: {self.brand}")

# Further derived class
class ElectricCar(Car):
    def __init__(self, vehicle_type, brand, battery_capacity):
        super().__init__(vehicle_type, brand)
        self.battery = battery_capacity

    def display_info(self):
        super().display_info()
        print(f"Battery Capacity: {self.battery} kWh")

# Example usage
my_electric_car = ElectricCar("Four-wheeler", "Tesla", 75)
my_electric_car.display_info()

# %%
#4. Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes Sparrow and Penguin that override the fly() method.



Ans:-

# Base class
class Bird:
    def fly(self):
        print("Bird is flying.")

# Derived class 1
class Sparrow(Bird):
    def fly(self):
        print("Sparrow flies high in the sky.")

# Derived class 2
class Penguin(Bird):
    def fly(self):
        print("Penguins can't fly, they swim instead.")

# Polymorphism demonstration
def show_flying_ability(bird):
    bird.fly()

# Create objects
sparrow = Sparrow()
penguin = Penguin()

# Call the function with different objects
show_flying_ability(sparrow)  # Output: Sparrow flies high in the sky.
show_flying_ability(penguin)  # Output: Penguins can't fly, they swim instead.

# %%
#5. Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes balance and methods to deposit, withdraw, and check balance.




Ans:-

class BankAccount:
    def __init__(self, initial_balance=0):
        self.__balance = initial_balance  # Private attribute

    # Method to deposit money
    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print(f"Deposited: ${amount}")
        else:
            print("Deposit amount must be positive.")

    # Method to withdraw money
    def withdraw(self, amount):
        if amount <= self.__balance:
            self.__balance -= amount
            print(f"Withdrawn: ${amount}")
        else:
            print("Insufficient balance.")

    # Method to check balance
    def check_balance(self):
        print(f"Current Balance: ${self.__balance}")

# Example usage
account = BankAccount(100)  # Starting with $100
account.check_balance()
account.deposit(50)
account.withdraw(30)
account.check_balance()

# Trying to access private attribute directly (not recommended)
# print(account.__balance)  # This will raise an AttributeError

# %%
#6. Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar and Piano that implement their own version of play().


Ans:-
class Instrument:
    def play(self):
        print("Playing an instrument")

class Guitar(Instrument):
    def play(self):
        print("Strumming the guitar")

class Piano(Instrument):
    def play(self):
        print("Playing the piano")

# Demonstration
instruments = [Guitar(), Piano()]
for inst in instruments:
    inst.play()

# %%
#7. Create a class MathOperations with a class method add_numbers() to add two numbers and a static method subtract_numbers() to subtract two numbers.


Ans:-
class MathOperations:
    @classmethod
    def add_numbers(cls, a, b):
        return a + b

    @staticmethod
    def subtract_numbers(a, b):
        return a - b

# Demonstration
print(MathOperations.add_numbers(5, 3))      # Output: 8
print(MathOperations.subtract_numbers(5, 3)) # Output: 2

# %%
#8. Implement a class Person with a class method to count the total number of persons created.


Ans:-
class Person:
    count = 0

    def __init__(self, name):
        self.name = name
        Person.count += 1

    @classmethod
    def total_persons(cls):
        return cls.count

# Demonstration
p1 = Person("Alice")
p2 = Person("Bob")
print(Person.total_persons())  # Output: 2

# %%
#9. Write a class Fraction with attributes numerator and denominator. Override the str method to display the fraction as "numerator/denominator.

Ans:-

class Fraction:
    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator

    def __str__(self):
        return f"{self.numerator}/{self.denominator}"

# Demonstration
f = Fraction(3, 4)
print(f)  # Output: 3/4

# %%
#10. Demonstrate operator overloading by creating a class Vector and overriding the add method to add two vectors.

Ans:-

class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)

# %%
#11. Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is {name} and I am {age} years old."

Ans:-
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

# Demonstration
p = Person("Charlie", 30)
p.greet()

# %%
#12. Implement a class Student with attributes name and grades. Create a method average_grade() to compute the average of the grades.
Ans:-

class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades

    def average_grade(self):
        return sum(self.grades) / len(self.grades)

# Demonstration
s = Student("Dana", [85, 90, 78])
print(s.average_grade())  # Output: 84.33...


#13. Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the area.
Ans:-

class Rectangle:
    def __init__(self):
        self.length = 0
        self.width = 0

    def set_dimensions(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

# Demonstration
rect = Rectangle()
rect.set_dimensions(5, 4)
print(rect.area())  # Output: 20


# 14. Create a class Employee with a method calculate_salary() that computes the salary based on hours worked and hourly rate. Create a derived class Manager that adds a bonus to the salary.
Ans:-
class Employee:
    def calculate_salary(self, hours_worked, hourly_rate):
        return hours_worked * hourly_rate

class Manager(Employee):
    def calculate_salary(self, hours_worked, hourly_rate, bonus=0):
        base_salary = super().calculate_salary(hours_worked, hourly_rate)
        return base_salary + bonus

# Demonstration
e = Employee()
m = Manager()
print(e.calculate_salary(40, 20))          # Output: 800
print(m.calculate_salary(40, 20, bonus=200))  # Output: 1000




#15. Create a class Product with attributes name, price, and quantity. Implement a method total_price() that calculates the total price of the product.

Ans:-
class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    def total_price(self):
        return self.price * self.quantity

# Demonstration
p = Product("Laptop", 1000, 2)
print(p.total_price())  # Output: 2000


#16. Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that mplement the sound() method.

Ans:-
from abc import ABC, abstractmethod

class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass

class Cow(Animal):
    def sound(self):
        return "Moo"

class Sheep(Animal):
    def sound(self):
        return "Baa"

# Demonstration
animals = [Cow(), Sheep()]
for animal in animals:
    print(animal.sound())  # Output: Moo, Baa


#17. Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that returns a formatted string with the book's details.
Ans:-
class Book:
    def __init__(self, title, author, year_published):
        self.title = title
        self.author = author
        self.year_published = year_published

    def get_book_info(self):
        return f"'{self.title}' by {self.author}, published in {self.year_published}"

# Demonstration
book = Book("1984", "George Orwell", 1949)
print(book.get_book_info())



#18. Create a class House with attributes address and price. Create a derived class Mansion that adds an attribute number_of_rooms.

Ans:-

class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price

class Mansion(House):
    def __init__(self, address, price, number_of_rooms):
        super().__init__(address, price)
        self.number_of_rooms = number_of_rooms

# Demonstration
mansion = Mansion("123 Luxury St", 5000000, 10)
print(f"{mansion.address}, Price: ${mansion.price}, Rooms: {mansion.number_of_rooms}")
